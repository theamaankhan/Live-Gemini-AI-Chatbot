# %%
# !pip install google-generativeai

# %%
import os
import time
import google.generativeai as genai
from datetime import datetime

# %%
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY") or input("Enter your Google API key: ")
genai.configure(api_key=GOOGLE_API_KEY)
# Out:
# Enter your Google API key: AIzaSyBfC9UpoOiwssSMXiPMSuUQFzPSHWU-b-s

# %%
model = genai.GenerativeModel("models/gemini-1.5-flash")

# %%
def get_timestamp():
    now = datetime.now()
    return now.strftime("%B %d, %Y %I:%M %p")

# %%
system_prompt = (
    f"You are Gemini, a helpful AI. The current date and time is {get_timestamp()}. "
    "Answer conversationally and use this as 'today' throughout."
)
chat = model.start_chat(history=[])

print("🤖 Gemini Chatbot (live) — type 'exit' to quit\n")

while True:
    user_input = input("Hi how can i help  you : ")
    if user_input.strip().lower() in ("exit", "quit", "bye"):
        print("👋 Goodbye!")
        break

    timestamp = get_timestamp()
    full_input = f"{system_prompt}\nUser: {user_input} (Current time: {timestamp})"

    try:
        response = chat.send_message(full_input, stream=True)
        print("Gemini:", end=" ", flush=True)
        for chunk in response:
            print(chunk.text, end="", flush=True)
        print("\n")
    except genai.Error as e:
        print(f"Error: {e}. Reinitializing session…")
        time.sleep(1)
        chat = model.start_chat(history=chat.history)

print("Chat session ended.")
# Out:
# 🤖 Gemini Chatbot (live) — type 'exit' to quit
#
# Hi how can i help  you : tell me about the ipl 2025
# Gemini: Hey there!  So you're asking about the IPL 2025 today, August 29th, 2025?  Well, the tournament itself hasn't started yet!  We're still in the pre-season, so there's no information on match results or a champion to speak of.
#
# However, I can tell you what we *do* know at this point.  We'd likely have seen the teams finalized, probably through auctions and player drafts a while back.  The schedule would be out, detailing match dates, venues, and broadcasting information.  There's probably been a lot of buzz in the media about team strategies and player form leading up to the start date.
#
# To find out specific details like the schedule, participating teams, and any news, I recommend checking reputable sports news websites or the official IPL website.  They’ll have all the up-to-date information you need once the tournament kicks off.
#
#
# ...
